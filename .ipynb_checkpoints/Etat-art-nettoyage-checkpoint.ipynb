# %% [markdown]
# ### Récupération des données :
#
# - https://github.com/jerrytigerxu/Beatles-NLP
# - Transformation du xlsx en csv.

# %% [markdown]
# ### État de l'art :
#
# - Référence : Compton, Todd (2017). *Who Wrote the Beatle Songs?  A History of Lennon-McCartney* :
#
# Comme le remarque Todd Compton, la plupart des chansons des Beatles ont été signées par les deux principaux chanteurs du groupe : John Lennon et Paul McCartney. Ce n'est pas un mystère cependant que ces chansons, pour une partie, n'ont été écrites que par un seul des deux. </br>
# La question de l'attribution des textes a été rendue encore plus compliquée du fait des Beatles eux-mêmes, qui ont cultivé la mésinformation par rapport à ces questions. De même, ce point aveugle tient sûrement aussi du fait que l'apport majeur des Beatles et la rupture qu'ils constituent dans la culture populaire ne tient pas forcément à leurs textes. </br>
# Certaines chansons relèvent d'une véritable collaboration, écrites pendant des sessions de trois heures, "*eyeball to eyeball*" dit John Lennon. </br>
# D'autres ont été écrites séparément par John Lennon ou Paul McCartney et l'un aidait l'autre à terminer d'écrire la chanson. Selon T. Compton, il s'agit de la forme la plus commune de leur collaboration. </br>
# Dans d'autres cas, des textes étaient écrits séparément par les deux chanteurs, puis rassemblés ensuite pour construire une chanson unique (ex : *Baby You're a Rich Man*"). </br>
#
# Lorsque l'on se penche sur les interviews donnés par les deux chanteurs, on se rend compte que ceux-ci se sont souvent contredits sur ces questions, l'un vis-à-vis de l'autre, mais aussi au sein de leur propre discours personnel. Pour ne prendre qu'un exemple parmi les nombreux développés par T. Compton, la chanson *Eleanor Rigby*, attribuée en grande partie à McCartney mais dont Lennon affirme dans un interview de 1970 avoir écrit près de 70% de la chanson, propos contredits par un des amis de McCartney, Pete Shotton, présent lors de la session, qui affirme que Lennon n'a pratiquement rien fait sur cette chanson. Lennon lui-même, dans un interview de 1981, explique qu'il a aidé à écrire une demie ligne de *Eleanor Rigby*, se contredisant avec ses propos tenus dix ans plus tôt. De même, dans un autre interview, répondant à la question de savoir quelles chansons étaient les plus marquantes dans sa collaboration avec McCartney au niveau de l'écriture, Lennon cite *Eleanor Rigby*. Pour une demie ligne ? C'est peu probable...
#
# Une vision diachronique sur les différentes périodes des Beatles peut s'avérer nécessaire pour tâcher de mieux comprendre cette collaboration.
#
# - Première période : "__the Beatles era__" : Brian Epstein, l'agent des Beatles, leur conseilla rapidement d'affirmer que toutes leurs chansons résultaient d'une écriture collaborative. En 1964, McCartney affirme : "*Sometimes maybe he'll write a whole song himself, or I will, but we always say that we've both written it*" ; et en 1966, d'affirmer : "*We both work on all our songs*". Au fil du temps cependant, et après la mort d'Epstein en 1967, cette position de revendication d'une écriture résolument collaborative se dissipa progressivement, à mesure qu'ils arrivaient aux albums de maturité, comme *Revolver and Sgt. Pepper*.
# - Deuxième période : "__after the breakup__" : très peu de temps après la rupture en 1970-1971, Lennon donna des interviews qui remirent en question l'attribution des chansons attribuées au couple Lennon-McCartney. Cependant, ces propos semblent davantage relever du ressentiment de Lennon vis-à-vis de McCartney à cette époque et de leurs désaccords. Compton écrit : "*During this period, John and Paul were publicly and heatedly disagreeing about many things, and attacked each other in interviews, at the same time that they were discussing autorship of songs. Naturally, bias would be present during a time of such heated emotional conflict*" (p. 6).
# - Troisième période : "__1980's to the present__" : cette troisième période se caractérise par une forme de retour sur les propos tenus pendant la deuxième période. Dans sa biographie *Paul McCartney : Many Years From Now*, McCartney affirme n'être en désaccord avec Lennon sur l'attribution de seulement deux chansons. En vérité, ces désaccords sont bien plus nombreux, mais l'on remarque que ces interviews ont eu tendance à reprendre la première posture de l'écriture purement collaborative.
#
# On note donc que l'histoire de l'écriture collaborative entre les deux auteurs se doublent des histoires et destins personnelles de ceux-ci, de  problématiques tenant à leur relation amicale, des tensions qui ont pu naître entre eux, mais aussi de l'image commerciale qui a été entretenue par leur agent, préférant mettre en avant la création collective plutôt que l'écriture individuelle au sein du groupe. </br>
# Si Todd Compton mène une étude en confrontant les sources, les différents interviews et propos des deux chanteurs, il convient pour nous de nous demander si une analyse à partir des textes et du style de ces chansons à l'attribution douteuse ne nous permettrait pas, pour certaines chansons tout du moins, de démêler le style propre de chacun des deux chanteurs.
#
# ---

# %% [markdown]
# ### Nettoyage des données :
#
# ---

# %%
# Librairie pandas (manipulation de données csv, dataframe, etc.)
import pandas as pd

# Import et lecture du corpus :
corpus = pd.read_csv('data/beatles_data.csv')

# %%
# Print dataframe shape
print(corpus.shape)
# Out:
# (218, 6)

# %%
#Print column values
print(corpus.columns.values)
# Out:
# ['Song' 'Album Debut' 'Songwriter(s)' 'Lead Vocal(s)' 'Year' 'Lyrics']

# %%
# Coup d'oeil sur les données, les variables, etc. :
corpus.head()
# Out:
#                      Song                                   Album Debut  \
# 0       "12-Bar Original"                                   Anthology 2
# 1   "Across the Universe"                                     Let It Be
# 2    "All I've Got to Do"  UK: With the Beatles\n US: Meet the Beatles!
# 3         "All My Loving"  UK: With the Beatles\n US: Meet the Beatles!
# 4  "All Things Must Pass"                                   Anthology 3
#
#                                        Songwriter(s) Lead Vocal(s)  Year  \
# 0  John Lennon\n Paul McCartney\n George Harrison...  Instrumental  1965
# 1                                             Lennon        Lennon  1968
# 2                                             Lennon        Lennon  1963
# 3                                          McCartney     McCartney  1963
# 4                                           Harrison      Harrison  1969
#
#                                               Lyrics
# 0                                                NaN
# 1  Words are flowing out like endless rain into a...
# 2  Whenever I want you around yeh \nAll I gotta d...
# 3  Close your eyes and I'll kiss you\nTomorrow I'...
# 4  Sunrise doesn't last all morning, \nA cloudbur...

# %% [markdown]
# ## Analyse et nettoyage des données :
# ---

# %%
# Analyse des observation à homogénéiser : 

## Dénombrement songwriters :

corpus['Songwriter(s)'].value_counts()
# Out:
# McCartney                                                                               60
# Lennon                                                                                  60
# Harrison                                                                                26
# McCartney\n (with Lennon)                                                               23
# Lennon\n McCartney                                                                      19
# Lennon\n (with McCartney)                                                               16
# Lennon\n McCartney\n Harrison\n Starr                                                    4
# McCartney and Harrison                                                                   1
# McCartney ("Step Inside Love”)\n Lennon–McCartney\n Harrison–Starr ("Los Paranoias”)     1
# McCartney\n Starr                                                                        1
# Lennon\n and McCartney                                                                   1
# Lennon and Harrison                                                                      1
# John Lennon\n Paul McCartney\n George Harrison\n Ringo Starr                             1
# McCartney (with Lennon)                                                                  1
# Starr                                                                                    1
# Lennon\n McCartney\n Starkey[d]                                                          1
# Lennon, McCartney, Harrison, Starr                                                       1
# Name: Songwriter(s), dtype: int64

# %%
# Visualisation sommaire / moche :

corpus['Songwriter(s)'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
#
# **Plusieurs remarques à faire ici** :
#
#     - On remarque évidemment l'absence d'homogénéisation des différentes observations
#     (==> nettoyage nécessaire des données).
#     - Également les retours chariot qui peuvent poser pb.
#
# **À modifier** :
#
#     - McCartney\n (with Lennon)
#     - Lennon\n McCartney
#     - Lennon\n (with McCartney)
#     - McCartney (with Lennon)
#     - Lennon\n and McCartney
#
# ==> 'Lennon-McCartney'
#
# ---

# %%
## Regex de nettoyage :

corpus_clean = corpus

## Sélection de la colonne, retrait retour chariot et homogénéisation des obs

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('\n','', 
                                                                      regex=True) # retour chariot

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('McCartney (with Lennon)',
                                                                      'Lennon-McCartney', regex=False) # Regex = False parenthèse

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('Lennon McCartney',
                                                                      'Lennon-McCartney', regex=False)

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('Lennon (with McCartney)',
                                                                      'Lennon-McCartney', regex=False)

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('McCartney (with Lennon)',
                                                                      'Lennon-McCartney', regex=False)

corpus_clean['Songwriter(s)'] = corpus_clean['Songwriter(s)'].replace('Lennon and McCartney',
                                                                      'Lennon-McCartney', regex=False)

# Aperçu du résultat :

corpus_clean[0:15]
# Out:
#                          Song                                   Album Debut  \
# 0           "12-Bar Original"                                   Anthology 2
# 1       "Across the Universe"                                     Let It Be
# 2        "All I've Got to Do"  UK: With the Beatles\n US: Meet the Beatles!
# 3             "All My Loving"  UK: With the Beatles\n US: Meet the Beatles!
# 4      "All Things Must Pass"                                   Anthology 3
# 5          "All Together Now"                              Yellow Submarine
# 6      "All You Need Is Love"                          Magical Mystery Tour
# 7            "And I Love Her"    UK: A Hard Day's Night\n US: Something New
# 8    "And Your Bird Can Sing"        UK: Revolver\n US: Yesterday and Today
# 9              "Another Girl"                                         Help!
# 10          "Any Time at All"    UK: A Hard Day's Night\n US: Something New
# 11               "Ask Me Why"  UK: Please Please Me\n US: The Early Beatles
# 12  "Baby, You're a Rich Man"                          Magical Mystery Tour
# 13          "Baby's in Black"        UK: Beatles for Sale\n US: Beatles '65
# 14      "Back in the U.S.S.R.                                   The Beatles
#
#                                         Songwriter(s)       Lead Vocal(s)  \
# 0   John Lennon Paul McCartney George Harrison Rin...        Instrumental
# 1                                              Lennon              Lennon
# 2                                              Lennon              Lennon
# 3                                           McCartney           McCartney
# 4                                            Harrison            Harrison
# 5                                    Lennon-McCartney           McCartney
# 6                                              Lennon              Lennon
# 7                                    Lennon-McCartney           McCartney
# 8                                    Lennon-McCartney              Lennon
# 9                                           McCartney           McCartney
# 10                                   Lennon-McCartney              Lennon
# 11                                   Lennon-McCartney              Lennon
# 12                                   Lennon-McCartney              Lennon
# 13                                   Lennon-McCartney  Lennon\n McCartney
# 14                                          McCartney           McCartney
#
#     Year                                             Lyrics
# 0   1965                                                NaN
# 1   1968  Words are flowing out like endless rain into a...
# 2   1963  Whenever I want you around yeh \nAll I gotta d...
# 3   1963  Close your eyes and I'll kiss you\nTomorrow I'...
# 4   1969  Sunrise doesn't last all morning, \nA cloudbur...
# 5   1967  One two three four\nCan I have a little more\n...
# 6   1967  Love, love, love\nLove, love, love\nLove, love...
# 7   1964  I give her all my love\nThat's all I do\nAnd i...
# 8   1966  You tell me that you've got everything you wan...
# 9   1965  For I have got another girl, another girl\nYou...
# 10  1964  Any time at all, any time at all, any time at ...
# 11  1963  I love you, 'cause you tell me things I want t...
# 12  1967  How does it feel to be\nOne of the beautiful p...
# 13  1964  Oh dear, what can I do?\nBaby's in black and I...
# 14  1968  Flew in from Miami Beach BOAC\nDidn't get to b...

# %%
# On compte à nouveau :

corpus_clean['Songwriter(s)'].value_counts()
# Out:
# McCartney                                                                           60
# Lennon                                                                              60
# Lennon-McCartney                                                                    60
# Harrison                                                                            26
# Lennon McCartney Harrison Starr                                                      4
# John Lennon Paul McCartney George Harrison Ringo Starr                               1
# Lennon and Harrison                                                                  1
# McCartney and Harrison                                                               1
# McCartney ("Step Inside Love”) Lennon–McCartney Harrison–Starr ("Los Paranoias”)     1
# Starr                                                                                1
# Lennon McCartney Starkey[d]                                                          1
# Lennon, McCartney, Harrison, Starr                                                   1
# McCartney Starr                                                                      1
# Name: Songwriter(s), dtype: int64

# %%
# Viz :

corpus_clean['Songwriter(s)'].value_counts().plot(kind='barh')

## 60 / 60 / 60, pratique...!
# Out:
# <AxesSubplot:>

# %%
# Sélection des chansons qui ont été seulement écrites par Lennon, Lennon-McCartney, McCartney.

# If you have multiple values you want to include, put them in a list (or more generally, any iterable) and use isin:

corpus_clean_select = corpus_clean.loc[corpus_clean['Songwriter(s)'].isin(['Lennon','McCartney', 'Lennon-McCartney'])]

corpus_clean_select[1:15]
# Out:
#                              Song  \
# 2            "All I've Got to Do"
# 3                 "All My Loving"
# 5              "All Together Now"
# 6          "All You Need Is Love"
# 7                "And I Love Her"
# 8        "And Your Bird Can Sing"
# 9                  "Another Girl"
# 10              "Any Time at All"
# 11                   "Ask Me Why"
# 12      "Baby, You're a Rich Man"
# 13              "Baby's in Black"
# 14          "Back in the U.S.S.R.
# 15                    "Bad to Me"
# 16  "The Ballad of John and Yoko"
#
#                                      Album Debut     Songwriter(s)  \
# 2   UK: With the Beatles\n US: Meet the Beatles!            Lennon
# 3   UK: With the Beatles\n US: Meet the Beatles!         McCartney
# 5                               Yellow Submarine  Lennon-McCartney
# 6                           Magical Mystery Tour            Lennon
# 7     UK: A Hard Day's Night\n US: Something New  Lennon-McCartney
# 8         UK: Revolver\n US: Yesterday and Today  Lennon-McCartney
# 9                                          Help!         McCartney
# 10    UK: A Hard Day's Night\n US: Something New  Lennon-McCartney
# 11  UK: Please Please Me\n US: The Early Beatles  Lennon-McCartney
# 12                          Magical Mystery Tour  Lennon-McCartney
# 13        UK: Beatles for Sale\n US: Beatles '65  Lennon-McCartney
# 14                                   The Beatles         McCartney
# 15           The Beatles Bootleg Recordings 1963            Lennon
# 16                  UK: 1967–1970\n US: Hey Jude            Lennon
#
#                 Lead Vocal(s)  Year  \
# 2                      Lennon  1963
# 3                   McCartney  1963
# 5                   McCartney  1967
# 6                      Lennon  1967
# 7                   McCartney  1964
# 8                      Lennon  1966
# 9                   McCartney  1965
# 10                     Lennon  1964
# 11                     Lennon  1963
# 12                     Lennon  1967
# 13         Lennon\n McCartney  1964
# 14                  McCartney  1968
# 15                     Lennon  1963
# 16  Lennon\n (with McCartney)  1969
#
#                                                Lyrics
# 2   Whenever I want you around yeh \nAll I gotta d...
# 3   Close your eyes and I'll kiss you\nTomorrow I'...
# 5   One two three four\nCan I have a little more\n...
# 6   Love, love, love\nLove, love, love\nLove, love...
# 7   I give her all my love\nThat's all I do\nAnd i...
# 8   You tell me that you've got everything you wan...
# 9   For I have got another girl, another girl\nYou...
# 10  Any time at all, any time at all, any time at ...
# 11  I love you, 'cause you tell me things I want t...
# 12  How does it feel to be\nOne of the beautiful p...
# 13  Oh dear, what can I do?\nBaby's in black and I...
# 14  Flew in from Miami Beach BOAC\nDidn't get to b...
# 15  If you ever leave me, I'll be sad and blue\nDo...
# 16  Standing in the dock at Southampton\nTrying to...

# %%
# Si on veut trois corpus distincts :

# corpus_Lennon = corpus_clean.loc[(corpus_clean['Songwriter(s)'] == "Lennon")]
# corpus_McCartney = corpus_clean.loc[(corpus_clean['Songwriter(s)'] == "McCartney")]
# corpus_LMC = corpus_clean.loc[(corpus_clean['Songwriter(s)'] == "Lennon-McCartney")]

# %%
# TODO : nettoyage dans les Lyrics '\n'

# %% [markdown]
# ### Tokénisation, lemmatisation, étiquetage morphosyntaxique :
# ---
#
# **Objectif** :
#
#     - Avoir un tableau avec mot / lemme / POS / Oeuvre / Songwriter.
#
# ==> Boîte à outils SpaCy : https://spacy.io/api/tokenizer
# ==> https://spacy.io/usage/linguistic-features

# %%
# Installation de spacy :

# pip install spacy

# %%
# Construction :
from spacy.lang.en import English
nlp = English()
# Create a Tokenizer with the default settings for English
# including punctuation rules and exceptions
tokenizer = nlp.tokenizer

# %%
import spacy

# Petit réglage pour permettre d'écrire sur les données...
# (sécurité panda)

pd.options.mode.chained_assignment = None  # default='warn' (Cf. https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas)

corpus_test = corpus_clean_select

corpus_test['words'] = corpus_test['Lyrics'].apply(lambda x: nlp.tokenizer(str(x)))
# df['sents'] = df['text'].apply(lambda x: list(nlp(x).sents))
# Réf : https://stackoverflow.com/questions/46981137/tokenizing-using-pandas-and-spacy

# Note that nlp by default runs the entire SpaCy pipeline, which includes part-of-speech tagging, parsing and named entity recognition. You can significantly speed up your code by using nlp.tokenizer(x) instead of nlp(x), or by disabling parts of the pipeline when you load the model. E.g. nlp = spacy.load('en', parser=False, entity=False).

# Transform data using spaCy
# nlp = spacy.load("en_core_web_sm")
# WARNING: takes a long time!
# corpus_test['words'] = corpus_test['Lyrics'].apply(lambda x: [sent.text for sent in nlp(x).sents])

corpus_test.head()
# Out:
#                      Song                                   Album Debut  \
# 1   "Across the Universe"                                     Let It Be
# 2    "All I've Got to Do"  UK: With the Beatles\n US: Meet the Beatles!
# 3         "All My Loving"  UK: With the Beatles\n US: Meet the Beatles!
# 5      "All Together Now"                              Yellow Submarine
# 6  "All You Need Is Love"                          Magical Mystery Tour
#
#       Songwriter(s) Lead Vocal(s)  Year  \
# 1            Lennon        Lennon  1968
# 2            Lennon        Lennon  1963
# 3         McCartney     McCartney  1963
# 5  Lennon-McCartney     McCartney  1967
# 6            Lennon        Lennon  1967
#
#                                               Lyrics  \
# 1  Words are flowing out like endless rain into a...
# 2  Whenever I want you around yeh \nAll I gotta d...
# 3  Close your eyes and I'll kiss you\nTomorrow I'...
# 5  One two three four\nCan I have a little more\n...
# 6  Love, love, love\nLove, love, love\nLove, love...
#
#                                                words
# 1  (Words, are, flowing, out, like, endless, rain...
# 2  (Whenever, I, want, you, around, yeh, \n, All,...
# 3  (Close, your, eyes, and, I, 'll, kiss, you, \n...
# 5  (One, two, three, four, \n, Can, I, have, a, l...
# 6  (Love, ,, love, ,, love, \n, Love, ,, love, ,,...

# %%
# https://towardsdatascience.com/tokenize-text-columns-into-sentences-in-pandas-2c08bc1ca790
corpus_test = corpus_test.explode("words", ignore_index=True)
corpus_test.head()
# The explode() function is used to transform each element of a list-like to a row, 
# replicating the index values. Returns: Series- Exploded lists to rows; index will 

# be duplicated for these rows.
# Out:
#                     Song Album Debut Songwriter(s) Lead Vocal(s)  Year  \
# 0  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 1  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 2  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 3  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 4  "Across the Universe"   Let It Be        Lennon        Lennon  1968
#
#                                               Lyrics    words
# 0  Words are flowing out like endless rain into a...    Words
# 1  Words are flowing out like endless rain into a...      are
# 2  Words are flowing out like endless rain into a...  flowing
# 3  Words are flowing out like endless rain into a...      out
# 4  Words are flowing out like endless rain into a...     like

# %%
# À faire : téléchargement du modèle :   

# python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")

## Méthode :

## Cf. https://stackoverflow.com/questions/44395656/applying-spacy-parser-to-pandas-dataframe-w-multiprocessing

## Spacy is highly optimised and does the multiprocessing for you. 
## As a result, I think your best bet is to take the data out of 
## the Dataframe and pass it to the Spacy pipeline as a list rather 
## than trying to use .apply directly.
## You then need to the collate the results of the parse, and put 
## this back into the Dataframe. 

lemma = []
pos = []

for doc in nlp.pipe(corpus_test['words'].astype('unicode').values, batch_size=50):
    if doc.has_annotation("DEP"):
        #tokens.append([n.text for n in doc])
        lemma.append([n.lemma_ for n in doc])
        pos.append([n.pos_ for n in doc])
    else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
        # tokens.append(None)
        lemma.append(None)
        pos.append(None)
        
# corpus_test['tokens'] = tokens
corpus_test['lemma'] = lemma
corpus_test['pos'] = pos

# %%
# Regard sur les données : 

corpus_test[0:5]
# Out:
#                     Song Album Debut Songwriter(s) Lead Vocal(s)  Year  \
# 0  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 1  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 2  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 3  "Across the Universe"   Let It Be        Lennon        Lennon  1968
# 4  "Across the Universe"   Let It Be        Lennon        Lennon  1968
#
#                                               Lyrics    words   lemma     pos
# 0  Words are flowing out like endless rain into a...    Words  [word]  [NOUN]
# 1  Words are flowing out like endless rain into a...      are    [be]   [AUX]
# 2  Words are flowing out like endless rain into a...  flowing  [flow]  [VERB]
# 3  Words are flowing out like endless rain into a...      out   [out]   [ADP]
# 4  Words are flowing out like endless rain into a...     like  [like]  [INTJ]

# %%
len(corpus_test)
# Out:
# 40756

# %%
# Vérification qu'il n'y a pas de pb d'alignement entre words / lemma / pos
corpus_test.tail()
# Out:
#                                       Song Album Debut Songwriter(s)  \
# 40751  "You've Got to Hide Your Love Away"       Help!        Lennon
# 40752  "You've Got to Hide Your Love Away"       Help!        Lennon
# 40753  "You've Got to Hide Your Love Away"       Help!        Lennon
# 40754  "You've Got to Hide Your Love Away"       Help!        Lennon
# 40755  "You've Got to Hide Your Love Away"       Help!        Lennon
#
#       Lead Vocal(s)  Year                                             Lyrics  \
# 40751        Lennon  1965  Here I stand head in hand\nTurn my face to the...
# 40752        Lennon  1965  Here I stand head in hand\nTurn my face to the...
# 40753        Lennon  1965  Here I stand head in hand\nTurn my face to the...
# 40754        Lennon  1965  Here I stand head in hand\nTurn my face to the...
# 40755        Lennon  1965  Here I stand head in hand\nTurn my face to the...
#
#       words   lemma     pos
# 40751    to    [to]   [ADP]
# 40752  hide  [hide]  [VERB]
# 40753  your  [your]  [PRON]
# 40754  love  [love]  [NOUN]
# 40755  away  [away]   [ADV]

# %% [markdown]
# ## Analyse supervisée

# %%
# Turning the corpus into the expected format for our functions
import jagen_will.preproc.tuyau as tuy
import jagen_will.preproc.features_extract as fex
from jagen_will.preproc.text_count import count_process

myTexts = []
    
# extract features

#for index, row in corpus_clean_select.iterrows():
#    if isinstance(row["Lyrics"], str) and row["Lyrics"] is not "":
#        myTexts.append({"name": row["Song"], "aut": row["Songwriter(s)"], "text": tuy.normalise(row["Lyrics"]), "lang": 'en'})

        
### HACK: j'écris les données dont on a besoin pour l'usage tradi du module
for index, row in corpus_clean_select.iterrows():
    if isinstance(row["Lyrics"], str) and row["Lyrics"] is not "":
        print("data/songs_files/"+row["Songwriter(s)"]+"_"+row["Song"].replace('"', '').replace(' ','-')+'.txt')
        with open("data/songs_files/"+row["Songwriter(s)"]+"_"+row["Song"].replace('"', '').replace(' ','-')+'.txt', 'w') as f:
            f.write(row["Lyrics"])
        
#        with open("")
        
#        myTexts.append({"name": row["Song"], "aut": row["Songwriter(s)"], "text": tuy.normalise(row["Lyrics"]), "lang": 'en'})

# Now, you can use the CLI for jagen_will…
# Out:
# data/songs_files/Lennon_Across-the-Universe.txt
# data/songs_files/Lennon_All-I've-Got-to-Do.txt
# data/songs_files/McCartney_All-My-Loving.txt
# data/songs_files/Lennon-McCartney_All-Together-Now.txt
# data/songs_files/Lennon_All-You-Need-Is-Love.txt
# data/songs_files/Lennon-McCartney_And-I-Love-Her.txt
# data/songs_files/Lennon-McCartney_And-Your-Bird-Can-Sing.txt
# data/songs_files/McCartney_Another-Girl.txt
# data/songs_files/Lennon-McCartney_Any-Time-at-All.txt
# data/songs_files/Lennon-McCartney_Ask-Me-Why.txt
# data/songs_files/Lennon-McCartney_Baby,-You're-a-Rich-Man.txt
# data/songs_files/Lennon-McCartney_Baby's-in-Black.txt
# data/songs_files/McCartney_Back-in-the-U.S.S.R..txt
# data/songs_files/Lennon_Bad-to-Me.txt
# data/songs_files/Lennon_The-Ballad-of-John-and-Yoko.txt
# data/songs_files/Lennon_Because.txt
# data/songs_files/Lennon-McCartney_Because-I-Know-You-Love-Me-So.txt
# data/songs_files/Lennon-McCartney_Being-for-the-Benefit-of-Mr.-Kite!.txt
# data/songs_files/Lennon-McCartney_Birthday.txt
# data/songs_files/McCartney_Blackbird.txt
# data/songs_files/McCartney_Can't-Buy-Me-Love.txt
# data/songs_files/McCartney_Carry-That-Weight.txt
# data/songs_files/Lennon_Child-of-Nature.txt
# data/songs_files/McCartney_Come-and-Get-It.txt
# data/songs_files/Lennon_Come-Together.txt
# data/songs_files/Lennon_The-Continuing-Story-of-Bungalow-Bill.txt
# data/songs_files/Lennon_Cry-Baby-Cry”.txt
# data/songs_files/Lennon-McCartney_A-Day-in-the-Life.txt
# data/songs_files/Lennon-McCartney_Day-Tripper.txt
# data/songs_files/Lennon_Dear-Prudence.txt
# data/songs_files/Lennon_Dig-a-Pony.txt
# data/songs_files/Lennon_Do-You-Want-to-Know-a-Secret?.txt
# data/songs_files/Lennon-McCartney_Doctor-Robert.txt
# data/songs_files/Lennon_Don't-Let-Me-Down.txt
# data/songs_files/Lennon-McCartney_Drive-My-Car.txt
# data/songs_files/Lennon-McCartney_Eight-Days-a-Week.txt
# data/songs_files/Lennon-McCartney_Eleanor-Rigby.txt
# data/songs_files/McCartney_The-End.txt
# data/songs_files/McCartney_Every-Little-Thing.txt
# data/songs_files/Lennon_Everybody's-Got-Something-to-Hide-Except-Me-and-My-Monkey.txt
# data/songs_files/McCartney_Fixing-a-Hole.txt
# data/songs_files/Lennon-McCartney_Fancy-My-Chances-with-You.txt
# data/songs_files/McCartney_The-Fool-on-the-Hill.txt
# data/songs_files/McCartney_For-No-One.txt
# data/songs_files/Lennon-McCartney_From-Me-to-You.txt
# data/songs_files/McCartney_Get-Back.txt
# data/songs_files/Lennon-McCartney_Getting-Better.txt
# data/songs_files/Lennon_Girl.txt
# data/songs_files/Lennon_Glass-Onion.txt
# data/songs_files/McCartney_Golden-Slumbers.txt
# data/songs_files/Lennon-McCartney_Good-Day-Sunshine.txt
# data/songs_files/Lennon_Good-Morning-Good-Morning.txt
# data/songs_files/Lennon_Good-Night.txt
# data/songs_files/McCartney_Got-to-Get-You-into-My-Life.txt
# data/songs_files/Lennon_Happiness-Is-a-Warm-Gun.txt
# data/songs_files/Lennon-McCartney_A-Hard-Day's-Night.txt
# data/songs_files/McCartney_Heather.txt
# data/songs_files/McCartney_Hello,-Goodbye.txt
# data/songs_files/Lennon_Hello-Little-Girl.txt
# data/songs_files/Lennon-McCartney_Help!.txt
# data/songs_files/McCartney_Helter-Skelter.txt
# data/songs_files/McCartney_Her-Majesty.txt
# data/songs_files/McCartney_Here,-There-and-Everywhere.txt
# data/songs_files/Lennon_Hey-Bulldog.txt
# data/songs_files/McCartney_Hey-Jude.txt
# data/songs_files/Lennon-McCartney_Hold-Me-Tight.txt
# data/songs_files/McCartney_Honey-Pie.txt
# data/songs_files/Lennon_I-Am-the-Walrus.txt
# data/songs_files/Lennon_I-Call-Your-Name.txt
# data/songs_files/Lennon_I-Don't-Want-to-Spoil-the-Party.txt
# data/songs_files/Lennon_I-Feel-Fine.txt
# data/songs_files/McCartney_I-Lost-My-Little-Girl.txt
# data/songs_files/Lennon-McCartney_I-Saw-Her-Standing-There.txt
# data/songs_files/Lennon_I-Should-Have-Known-Better.txt
# data/songs_files/Lennon-McCartney_I-Wanna-Be-Your-Man.txt
# data/songs_files/Lennon-McCartney_I-Want-to-Hold-Your-Hand.txt
# data/songs_files/Lennon_I-Want-You-(She's-So-Heavy).txt
# data/songs_files/McCartney_I-Will.txt
# data/songs_files/Lennon_If-I-Fell.txt
# data/songs_files/Lennon-McCartney_If-You've-Got-Trouble.txt
# data/songs_files/Lennon_I'll-Be-Back.txt
# data/songs_files/McCartney_I'll-Be-on-My-Way.txt
# data/songs_files/Lennon_I'll-Cry-Instead.txt
# data/songs_files/McCartney_I'll-Follow-the-Sun.txt
# data/songs_files/Lennon-McCartney_I'll-Get-You.txt
# data/songs_files/Lennon_I'm-a-Loser.txt
# data/songs_files/McCartney_I'm-Down.txt
# data/songs_files/Lennon-McCartney_I'm-Happy-Just-to-Dance-with-You.txt
# data/songs_files/Lennon_I'm-In-Love.txt
# data/songs_files/McCartney_I'm-Looking-Through-You.txt
# data/songs_files/Lennon_I'm-Only-Sleeping.txt
# data/songs_files/Lennon_I'm-So-Tired.txt
# data/songs_files/Lennon-McCartney_In-My-Life.txt
# data/songs_files/Lennon-McCartney_It-Won't-Be-Long.txt
# data/songs_files/Lennon_It's-Only-Love.txt
# data/songs_files/Lennon-McCartney_I've-Got-a-Feeling.txt
# data/songs_files/McCartney_I've-Just-Seen-a-Face.txt
# data/songs_files/Lennon_Julia.txt
# data/songs_files/McCartney_Junk.txt
# data/songs_files/Lennon-McCartney_Lady-Madonna.txt
# data/songs_files/McCartney_Let-It-Be.txt
# data/songs_files/McCartney_Like-Dreamers-Do.txt
# data/songs_files/Lennon-McCartney_Little-Child.txt
# data/songs_files/McCartney_The-Long-and-Winding-Road.txt
# data/songs_files/Lennon-McCartney_Love-Me-Do.txt
# data/songs_files/Lennon-McCartney_Love-of-the-Loved.txt
# data/songs_files/McCartney_Lovely-Rita.txt
# data/songs_files/Lennon-McCartney_Lucy-in-the-Sky-with-Diamonds.txt
# data/songs_files/Lennon-McCartney_Magical-Mystery-Tour.txt
# data/songs_files/McCartney_Martha-My-Dear.txt
# data/songs_files/McCartney_Maxwell's-Silver-Hammer.txt
# data/songs_files/Lennon_Mean-Mr.-Mustard.txt
# data/songs_files/Lennon-McCartney_Michelle.txt
# data/songs_files/Lennon-McCartney_Misery.txt
# data/songs_files/McCartney_Mother-Nature's-Son.txt
# data/songs_files/McCartney_The-Night-Before.txt
# data/songs_files/Lennon-McCartney_No-Reply.txt
# data/songs_files/Lennon-McCartney_Norwegian-Wood-(This-Bird-Has-Flown).txt
# data/songs_files/Lennon_Not-a-Second-Time.txt
# data/songs_files/Lennon-McCartney_Nowhere-Man.txt
# data/songs_files/McCartney_Ob-La-Di,-Ob-La-Da.txt
# data/songs_files/McCartney_Oh!-Darling.txt
# data/songs_files/Lennon_One-After-909.txt
# data/songs_files/McCartney_One-and-One-Is-Two.txt
# data/songs_files/McCartney_Paperback-Writer.txt
# data/songs_files/McCartney_Penny-Lane.txt
# data/songs_files/Lennon_Please-Please-Me.txt
# data/songs_files/Lennon_Polythene-Pam.txt
# data/songs_files/Lennon-McCartney_P.S.-I-Love-You.txt
# data/songs_files/Lennon_Rain.txt
# data/songs_files/Lennon_Real-Love.txt
# data/songs_files/Lennon_Revolution.txt
# data/songs_files/Lennon-McCartney_Rocky-Raccoon.txt
# data/songs_files/Lennon-McCartney_Run-for-Your-Life.txt
# data/songs_files/Lennon_Sexy-Sadie.txt
# data/songs_files/McCartney_Sgt.-Pepper's-Lonely-Hearts-Club-Band.txt
# data/songs_files/McCartney_Sgt.-Pepper's-Lonely-Hearts-Club-Band-(Reprise).txt
# data/songs_files/McCartney_She-Came-in-Through-the-Bathroom-Window.txt
# data/songs_files/Lennon-McCartney_She-Loves-You.txt
# data/songs_files/Lennon_She-Said-She-Said.txt
# data/songs_files/Lennon-McCartney_She's-a-Woman.txt
# data/songs_files/Lennon-McCartney_She's-Leaving-Home.txt
# data/songs_files/Lennon_Strawberry-Fields-Forever.txt
# data/songs_files/Lennon_Sun-King.txt
# data/songs_files/McCartney_Teddy-Boy.txt
# data/songs_files/Lennon-McCartney_Tell-Me-What-You-See.txt
# data/songs_files/Lennon_Tell-Me-Why.txt
# data/songs_files/Lennon-McCartney_Thank-You-Girl.txt
# data/songs_files/McCartney_That-Means-a-Lot.txt
# data/songs_files/Lennon-McCartney_There's-a-Place.txt
# data/songs_files/McCartney_Things-We-Said-Today.txt
# data/songs_files/Lennon_This-Boy.txt
# data/songs_files/Lennon_Ticket-to-Ride.txt
# data/songs_files/Lennon_Tomorrow-Never-Knows.txt
# data/songs_files/McCartney_Two-of-Us.txt
# data/songs_files/Lennon-McCartney_Wait.txt
# data/songs_files/Lennon-McCartney_Watching-Rainbows.txt
# data/songs_files/Lennon-McCartney_We-Can-Work-It-Out.txt
# data/songs_files/McCartney_What-You're-Doing.txt
# data/songs_files/Lennon_What's-The-New-Mary-Jane.txt
# data/songs_files/Lennon_When-I-Get-Home.txt
# data/songs_files/McCartney_When-I'm-Sixty-Four.txt
# data/songs_files/McCartney_Why-Don't-We-Do-It-in-the-Road?.txt
# data/songs_files/McCartney_Wild-Honey-Pie.txt
# data/songs_files/Lennon-McCartney_With-a-Little-Help-from-My-Friends.txt
# data/songs_files/McCartney_Woman.txt
# data/songs_files/Lennon-McCartney_The-Word.txt
# data/songs_files/Lennon-McCartney_Yellow-Submarine.txt
# data/songs_files/Lennon_Yer-Blues.txt
# data/songs_files/Lennon_Yes-It-Is.txt
# data/songs_files/McCartney_Yesterday.txt
# data/songs_files/Lennon_You-Can't-Do-That.txt
# data/songs_files/Lennon-McCartney_You-Know-My-Name-(Look-Up-the-Number).txt
# data/songs_files/McCartney_You-Never-Give-Me-Your-Money.txt
# data/songs_files/McCartney_You-Won't-See-Me.txt
# data/songs_files/Lennon-McCartney_You'll-Be-Mine.txt
# data/songs_files/McCartney_Your-Mother-Should-Know.txt
# data/songs_files/Lennon_You're-Going-to-Lose-That-Girl.txt
# data/songs_files/Lennon_You've-Got-to-Hide-Your-Love-Away.txt

# %%
#corpus_clean_select.iloc[27]
# Out:
# Song                                                "Cry Baby Cry”
# Album Debut                                            The Beatles
# Songwriter(s)                                               Lennon
# Lead Vocal(s)                            Lennon\n (with McCartney)
# Year                                                          1968
# Lyrics           Cry baby cry\nMake your mother sigh\nShe's old...
# Name: 32, dtype: object

# %%
#myTexts
# corpus_clean_select
my_feats = fex.get_feature_list(myTexts, feats='chars', n=3, relFreqs=True)
feat_list = [m[0] for m in my_feats]
myTexts = fex.get_counts(myTexts, feat_list=feat_list, feats="chars", n=3, relFreqs=True)
unique_texts = [text["name"] for text in myTexts]
